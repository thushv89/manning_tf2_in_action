# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 18})
import pandas as pd

# %%
_, ax = plt.subplots(figsize=(18,8))
pd.read_csv('language_trends.csv',index_col=0, header=0).plot(ax=ax)
ax.set_title("Popularity of programming languages (Google search trends)")
ax.set_ylabel("Popularity")
#df2 = pd.read_csv('tensorflow_pytorch_trends.csv', index_col=0, header=0)
# Out:
# Text(0, 0.5, 'Popularity')

# %%
_, ax = plt.subplots(figsize=(18,8))
pd.read_csv('tensorflow_pytorch_trends.csv', index_col=0, header=0).replace('<1',0).astype('int32').plot(ax=ax)
ax.set_title("Popularity of deep learning frameworks (Google search trends)")
ax.set_ylabel("Popularity")

# %%
df2 = 
df2 = df2

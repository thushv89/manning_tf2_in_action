# %% [markdown]
# # Chapter 6: Teaching Machines to See
#
# ## Image Classification
#
# In this, we will train a complex convolution neural network on an image classification dataset.
#
#
# <table align="left">
#     <td>
#         <a target="_blank" href="https://colab.research.google.com/github/thushv89/manning_tf2_in_action/blob/master/Ch06-Image-Classification-with-CNNs/6.1.Image_Classification.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#     </td>
# </table>

# %% [markdown]
# ## Importing necessary libraries

# %%
import tensorflow as tf
import tensorflow_hub as hub
import requests
import zipfile
import requests
import os
import time
import pandas as pd
import random
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, AvgPool2D, Dense, Concatenate, Flatten, Lambda, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.losses import CategoricalCrossentropy
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger
import numpy as np
from PIL import Image
import tensorflow.keras.backend as K
import pickle
from tensorflow.keras.models import load_model, Model

def fix_random_seed(seed):
    try:
        np.random.seed(seed)
    except NameError:
        print("Warning: Numpy is not imported. Setting the seed for Numpy failed.")
    try:
        tf.random.set_seed(seed)
    except NameError:
        print("Warning: TensorFlow is not imported. Setting the seed for TensorFlow failed.")
    try:
        random.seed(seed)
    except NameError:
        print("Warning: random module is not imported. Setting the seed for random failed.")

random_seed = 4321
# Fixing the random seed
fix_random_seed(random_seed)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except:
        print("Couldn't set memory_growth")
        pass
# Out:
# 2022-07-28 18:20:08.255376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:20:08.306682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:20:08.307151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# ## Downloading data
#
# For this chapter, we're going to use the tiny-imagenet dataset (200 categories of objects). This is a simplified version of the bigger and harder imagenet dataset (1000 categories of objects).

# %%
#Section 6.1 

import os
import requests
import zipfile

# Retrieve the data
if not os.path.exists(os.path.join('data','tiny-imagenet-200.zip')):
    url = "http://cs231n.stanford.edu/tiny-imagenet-200.zip"
    # Get the file from web
    r = requests.get(url)

    if not os.path.exists('data'):
        os.mkdir('data')
    
    # Write to a file
    with open(os.path.join('data','tiny-imagenet-200.zip'), 'wb') as f:
        f.write(r.content)
else:
    print("The zip file already exists.")
    
if not os.path.exists(os.path.join('data', 'tiny-imagenet-200')):
    with zipfile.ZipFile(os.path.join('data','tiny-imagenet-200.zip'), 'r') as zip_ref:
        zip_ref.extractall('data')
else:
    print("The extracted data already exists")
# Out:
# The zip file already exists.
# The extracted data already exists

# %% [markdown]
# ## Read the label information of the data
#
# The classes in tiny-imagenet are coded by an id (known as `wnid` (WordNetID)). Here we will decode these IDs to get class descriptions of each ID, so we know what we're dealing with

# %%
#Section 6.1
#Code listing 6.1

import os
import pandas as pd

# The file paths we're going to use
data_dir = os.path.join('data', 'tiny-imagenet-200')
wnids_path = os.path.join(data_dir, 'wnids.txt')
words_path = os.path.join(data_dir, 'words.txt')

def get_tiny_imagenet_classes(wnids_path, words_path):
    
    # Read the csv files
    # wninds.txt contains the wnids of the data in the dataset
    wnids = pd.read_csv(wnids_path, header=None, squeeze=True)
    # words.txt contains a mapping from wnid to the class description
    words = pd.read_csv(words_path, sep='\t', index_col=0, header=None)
    # Get only the class descriptions corresponding to the wnids in the dataset
    words_200 = words.loc[wnids].rename({1:'class'}, axis=1)
    
    words_200.index.name = 'wnid'
    return words_200.reset_index()

labels = get_tiny_imagenet_classes(wnids_path, words_path)
labels.head(n=25)
# Out:
# /tmp/ipykernel_3572/1569625529.py:16: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   wnids = pd.read_csv(wnids_path, header=None, squeeze=True)
#          wnid                                              class
# 0   n02124075                                       Egyptian cat
# 1   n04067472                                               reel
# 2   n04540053                                         volleyball
# 3   n04099969                              rocking chair, rocker
# 4   n07749582                                              lemon
# 5   n01641577                         bullfrog, Rana catesbeiana
# 6   n02802426                                         basketball
# 7   n09246464                              cliff, drop, drop-off
# 8   n07920052                                           espresso
# 9   n03970156                          plunger, plumber's helper
# 10  n03891332                                      parking meter
# 11  n02106662  German shepherd, German shepherd dog, German p...
# 12  n03201208                                dining table, board
# 13  n02279972  monarch, monarch butterfly, milkweed butterfly...
# 14  n02132136                    brown bear, bruin, Ursus arctos
# 15  n04146614                                         school bus
# 16  n07873807                                   pizza, pizza pie
# 17  n02364673                           guinea pig, Cavia cobaya
# 18  n04507155                                           umbrella
# 19  n03854065                                  organ, pipe organ
# 20  n03838899                            oboe, hautboy, hautbois
# 21  n03733131                                            maypole
# 22  n01443537                        goldfish, Carassius auratus
# 23  n07875152                                             potpie
# 24  n03544143                                          hourglass

# %% [markdown]
# ## How many training instances for each class are there?
#
# **Note**: If you run this after separating out the validation data, you'll see 450 instead of 500 in the `n_train` column.

# %%
#Section 6.1

import os
def get_image_count(data_dir):  
    """ Counts the number of jpeg files in a given folder"""
    if not os.path.exists(data_dir):
        return 0
    return len([f for f in os.listdir(data_dir) if f.lower().endswith('jpeg')])
    
# Here we use the apply function in conjunction with the get_image_count to get the count of images in each
# subfolder in the train directory
labels["n_train"] = labels["wnid"].apply(lambda x: get_image_count(os.path.join(data_dir, 'train', x, 'images')))
labels.head()
# Out:
#         wnid                  class  n_train
# 0  n02124075           Egyptian cat      500
# 1  n04067472                   reel      500
# 2  n04540053             volleyball      500
# 3  n04099969  rocking chair, rocker      500
# 4  n07749582                  lemon      500

# %% [markdown]
# ## Look at summary statistics of the `n_train` column
#
# Summary statistics is a great way to get an instant view of a column in a dataframe. It gives us important information like mean/standard deviation, etc.

# %%
labels["n_train"].describe()
# Out:
# count    200.0
# mean     500.0
# std        0.0
# min      500.0
# 25%      500.0
# 50%      500.0
# 75%      500.0
# max      500.0
# Name: n_train, dtype: float64

# %% [markdown]
# ## Understanding the image dimensions in the dataset
#
# Before moving on to modelling we need to understand the image dimensions (height and width).

# %%
#Section 6.1
#Code listing 6.2

import os
from PIL import Image
import pandas as pd

# A list that will hold image height and width information
image_sizes = []

# We will only look at the first 25 directories (to save time)
for wnid in labels["wnid"].iloc[:25]:
    img_dir = os.path.join('data', 'tiny-imagenet-200', 'train', wnid, 'images')
    for f in os.listdir(img_dir):
        # Only read the file if ends with JPEG
        if f.endswith('JPEG'):
            # Append the height and width to the list
            # e.g. [(img1.width, img1.height), (img2.width, img2.height), ...]
            image_sizes.append(Image.open(os.path.join(img_dir, f)).size)

# Using the format of image_sizes, we can directly create a dataframe
img_df = pd.DataFrame.from_records(image_sizes)
img_df.columns = ["width", "height"]
# Getting summary statistics of all columns
img_df.describe()
# Out:
#          width   height
# count  12500.0  12500.0
# mean      64.0     64.0
# std        0.0      0.0
# min       64.0     64.0
# 25%       64.0     64.0
# 50%       64.0     64.0
# 75%       64.0     64.0
# max       64.0     64.0

# %% [markdown]
# ## Bonus: Getting information about pixel values of the images

# %%
import os
import numpy as np
from PIL import Image
images = []
for wnid in labels["wnid"].iloc[:2]:
    img_dir = os.path.join('data', 'tiny-imagenet-200', 'train', wnid, 'images')
    for f in os.listdir(img_dir)[:10]:
        if f.endswith('JPEG'):
            img = np.array(Image.open(os.path.join(img_dir, f)))
            images.append((img.min(), img.max(), img.mean()))

img_df = pd.DataFrame.from_records(images)
img_df.columns = ["Min", "Max", "Mean"]
img_df.describe()
# Out:
#              Min        Max        Mean
# count  20.000000  20.000000   20.000000
# mean    0.650000  -3.150000  115.246729
# std     2.300458   8.041177   52.411007
# min     0.000000 -37.000000   45.075928
# 25%     0.000000  -1.000000   83.692464
# 50%     0.000000  -1.000000  108.461304
# 75%     0.000000  -1.000000  128.942668
# max    10.000000  -1.000000  219.116618

# %% [markdown]
# ## Creating the data generators
#
# In the dataset, we currently have a,
#
# * Training set: `train` directory
# * Testing set: `val` directory
#
# But to properly train a model we need three datasets,
#
# * Training set - Used to train the model
# * Validation set - Used to continuously monitor model performance while training
# * Testing set - Used to test the model, only after training finishes
#
# Therefore, we will separate a 10% from training data and feed this data through as a separate generator

# %%
#Section 6.2

from functools import partial

def get_test_labels_df(test_labels_path):
    """ Reading the test data labels for all files in the test set as a data frame """
    test_df = pd.read_csv(test_labels_path, sep='\t', index_col=None, header=None)
    test_df = test_df.iloc[:,[0,1]].rename({0:"filename", 1:"class"}, axis=1)
    return test_df

def get_train_valid_test_data_generators(batch_size, target_size):
    # Define a Keras ImageDataGenerator with image centering (subtract mean)
    
    image_gen = ImageDataGenerator(samplewise_center=True, validation_split=0.1)

    # Define a training data generator
    partial_flow_func = partial(
        image_gen.flow_from_directory, 
        directory=os.path.join('data','tiny-imagenet-200', 'train'), 
        target_size=target_size, classes=None,
        class_mode='categorical', batch_size=batch_size, 
        shuffle=True, seed=random_seed)
    
    # Get the training data subset
    train_gen = partial_flow_func(subset='training')
    # Get the validation data subset
    valid_gen = partial_flow_func(subset='validation')
    
    
    # Define a testing data generator
    # This function uses flow_from_dataframe instead of flow_from_directory
    test_df = get_test_labels_df(os.path.join('data','tiny-imagenet-200',  'val', 'val_annotations.txt'))
    test_gen = image_gen.flow_from_dataframe(
        test_df, directory=os.path.join('data','tiny-imagenet-200',  'val', 'images'), target_size=target_size, classes=None,
        class_mode='categorical', batch_size=batch_size, shuffle=False
    )
    return train_gen, valid_gen, test_gen

def data_gen_aux(gen):    
    # We need to modify our standard data generators to output the same target three times
    for x,y in gen:        
        yield x,(y,y,y)

batch_size = 128
target_size = (56, 56)
# Getting the train,valid, test data generators
train_gen, valid_gen, test_gen = get_train_valid_test_data_generators(batch_size, target_size)
# Modifying the data generators to fit the model targets
train_gen_aux = data_gen_aux(train_gen)
valid_gen_aux = data_gen_aux(valid_gen)
test_gen_aux = data_gen_aux(test_gen)
# Out:
# Found 90000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Found 10000 validated image filenames belonging to 200 classes.

# %% [markdown]
# ## Validating the consistency of validation data

# %%
from itertools import tee
all_labels = []
n_trials = 10

valid_gen_test = tee(valid_gen, n_trials)

for i in range(n_trials):    
    labels = []
    for j in range(5):
        _, ohe = next(valid_gen_test[i])
        # Convert one hot encoded to class labels
        labels.append(np.argmax(ohe, axis=-1))
        
    # Concat all labels
    labels = np.reshape(np.concatenate(labels, axis=0), (1,-1))        
    all_labels.append(labels)

# Concat all labels accross all trials
all_labels = np.concatenate(all_labels, axis=0)

# Assert the labels are equal across all trials
assert np.all(np.all(all_labels == all_labels[0,:], axis=0)), "Labels across multiple trials were not equal"
print("Successful! Labels across all trials were consistent.")
# Out:
# Successful! Labels across all trials were consistent.

# %% [markdown]
# ## Defining the Inception net v1
#
# Here we will be creating the Inception net v1 model using Keras Functional API
#
# ### Funtions that encapsulate various components of the Inception net v1 model

# %%
# Section 6.3
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, AvgPool2D, Dense, Concatenate, Flatten, Lambda, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.losses import CategoricalCrossentropy
import tensorflow.keras.backend as K

# Code listing 6.3
def stem(inp):
    conv1 = Conv2D(64, (7,7), strides=(1,1), activation='relu', padding='same')(inp)
    maxpool2 = MaxPool2D((3,3), strides=(2,2), padding='same')(conv1)
    lrn3 = Lambda(lambda x: tf.nn.local_response_normalization(x))(maxpool2)

    conv4 = Conv2D(64, (1,1), strides=(1,1), padding='same')(lrn3)
    conv5 = Conv2D(192, (3,3), strides=(1,1), activation='relu', padding='same')(conv4)
    lrn6 = Lambda(lambda x: tf.nn.local_response_normalization(x))(conv5)

    maxpool7 = MaxPool2D((3,3), strides=(1,1), padding='same')(lrn6)

    return maxpool7

# Code listing 6.4
def inception(inp, n_filters):

    # 1x1 layer
    # init argument defaults to glorot_uniform
    out1 = Conv2D(n_filters[0][0], (1,1), strides=(1,1), activation='relu', padding='same')(inp)

    # 1x1 followed by 3x3
    out2_1 = Conv2D(n_filters[1][0], (1,1), strides=(1,1), activation='relu', padding='same')(inp)
    out2_2 = Conv2D(n_filters[1][1], (3,3), strides=(1,1), activation='relu', padding='same')(out2_1)

    # 1x1 followed by 5x5
    out3_1 = Conv2D(n_filters[2][0], (1,1), strides=(1,1), activation='relu', padding='same')(inp)
    out3_2 = Conv2D(n_filters[2][1], (5,5), strides=(1,1), activation='relu', padding='same')(out3_1)

    # 3x3 (pool) followed by 1x1
    out4_1 = MaxPool2D((3,3), strides=(1,1), padding='same')(inp)
    out4_2 = Conv2D(n_filters[3][0], (1,1), strides=(1,1), activation='relu', padding='same')(out4_1)

    out = Concatenate(axis=-1)([out1, out2_2, out3_2, out4_2])
    return out

# Code listing 6.5
def aux_out(inp,name=None):    
    avgpool1 = AvgPool2D((5,5), strides=(3,3), padding='valid')(inp)
    conv1 = Conv2D(128, (1,1), activation='relu', padding='same')(avgpool1)
    flat = Flatten()(conv1)
    dense1 = Dense(1024, activation='relu')(flat)    
    aux_out = Dense(200, activation='softmax', name=name)(dense1)
    return aux_out

# %% [markdown]
# ### Defining the final model

# %%
# Section 6.3
# Code listing 6.6
def inception_v1():
    
    K.clear_session()
    
    inp = Input(shape=(56,56,3))
    stem_out = stem(inp)
    inc_3a = inception(stem_out, [(64,),(96,128),(16,32),(32,)])
    inc_3b = inception(inc_3a, [(128,),(128,192),(32,96),(64,)])

    maxpool = MaxPool2D((3,3), strides=(2,2), padding='same')(inc_3b)

    inc_4a = inception(maxpool, [(192,),(96,208),(16,48),(64,)])
    inc_4b = inception(inc_4a, [(160,),(112,224),(24,64),(64,)])

    aux_out1 = aux_out(inc_4a, name='aux1')

    inc_4c = inception(inc_4b, [(128,),(128,256),(24,64),(64,)])
    inc_4d = inception(inc_4c, [(112,),(144,288),(32,64),(64,)])
    inc_4e = inception(inc_4d, [(256,),(160,320),(32,128),(128,)])
    
    maxpool = MaxPool2D((3,3), strides=(2,2), padding='same')(inc_4e)
    
    aux_out2 = aux_out(inc_4d, name='aux2')

    inc_5a = inception(maxpool, [(256,),(160,320),(32,128),(128,)])
    inc_5b = inception(inc_5a, [(384,),(192,384),(48,128),(128,)])
    avgpool1 = AvgPool2D((7,7), strides=(1,1), padding='valid')(inc_5b)

    flat_out = Flatten()(avgpool1)
    out_main = Dense(200, activation='softmax', name='final')(flat_out)

    model = Model(inputs=inp, outputs=[out_main, aux_out1, aux_out2])
    model.compile(loss='categorical_crossentropy', 
                       optimizer='adam', metrics=['accuracy'])
    return model

model = inception_v1()
model.summary()
# Out:
# 2022-07-28 18:21:21.391556: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-28 18:21:21.392599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:21.393331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:21.393885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:22.494042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:22.494434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:22.494779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 18:21:22.495103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6350 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 56, 56, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   9472        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 64)   0           ['conv2d[0][0]']
#
#  lambda (Lambda)                (None, 28, 28, 64)   0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   4160        ['lambda[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 192)  110784      ['conv2d_1[0][0]']
#
#  lambda_1 (Lambda)              (None, 28, 28, 192)  0           ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['lambda_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  110720      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   12832       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 480)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 528)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0          ['concatenate_5[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_5[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 128)  102528      ['conv2d_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 832)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pooling2d_10[0][0]']
#  conv2d_49 (Conv2D)             (None, 7, 7, 320)    461120      ['conv2d_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 128)    102528      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 832)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 48)     39984       ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 384)    663936      ['conv2d_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 128)    153728      ['conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_12[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 512)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 1024)   0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_8[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['conv2d_27[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['conv2d_46[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['average_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 1024)         2098176     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         2098176     ['flatten_1[0][0]']
#
#  final (Dense)                  (None, 200)          205000      ['flatten_2[0][0]']
#
#  aux1 (Dense)                   (None, 200)          205000      ['dense[0][0]']
#
#  aux2 (Dense)                   (None, 200)          205000      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 10,918,280
# Trainable params: 10,918,280
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
# Section 6.4

def get_steps_per_epoch(n_data, batch_size):
    """ Given the data size and batch size, gives the number of steps to travers the full dataset """
    if n_data%batch_size==0:
        return int(n_data/batch_size)
    else:
        return int(n_data*1.0/batch_size)+1

# %%
# Section 6.4
# Code listing 6.7

from tensorflow.keras.callbacks import CSVLogger
import time
import os

# Create a directory called eval which stores model performance
if not os.path.exists('eval'):
    os.mkdir('eval')
    
# This will automatically log model performan to this file
csv_logger = CSVLogger(os.path.join('eval','1_eval_base.log'))
    
t1 = time.time() # Starting time

# Train the model, not how we are specifying steps_per_epoch and validation_steps
# to prevent the model from training forever
# We are also using the data generators (not actual data loaded to memory) to train the model
history = model.fit(
    train_gen_aux, validation_data=valid_gen_aux, 
    steps_per_epoch=get_steps_per_epoch(0.9*500*200,batch_size), 
    validation_steps=get_steps_per_epoch(0.1*500*200,batch_size),
    epochs=50, callbacks=[csv_logger]
)
t2 = time.time() # Ending time

# Print time it took
print("It took {} seconds to complete the training".format(t2-t1))
# Out:
# Epoch 1/50
# 2022-07-28 18:21:29.941693: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8400
# 2022-07-28 18:21:31.479960: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.194, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 704/704 [==============================] - 193s 262ms/step - loss: 14.5547 - final_loss: 4.9425 - aux1_loss: 4.7561 - aux2_loss: 4.8562 - final_accuracy: 0.0258 - aux1_accuracy: 0.0474 - aux2_accuracy: 0.0368 - val_loss: 13.2079 - val_final_loss: 4.5422 - val_aux1_loss: 4.2577 - val_aux2_loss: 4.4080 - val_final_accuracy: 0.0607 - val_aux1_accuracy: 0.0979 - val_aux2_accuracy: 0.0763
# Epoch 2/50
# 704/704 [==============================] - 184s 262ms/step - loss: 12.2247 - final_loss: 4.2296 - aux1_loss: 3.9186 - aux2_loss: 4.0766 - final_accuracy: 0.0948 - aux1_accuracy: 0.1462 - aux2_accuracy: 0.1189 - val_loss: 11.5159 - val_final_loss: 3.9503 - val_aux1_loss: 3.7262 - val_aux2_loss: 3.8394 - val_final_accuracy: 0.1310 - val_aux1_accuracy: 0.1758 - val_aux2_accuracy: 0.1487
# Epoch 3/50
# 704/704 [==============================] - 186s 265ms/step - loss: 10.8330 - final_loss: 3.7453 - aux1_loss: 3.4681 - aux2_loss: 3.6196 - final_accuracy: 0.1679 - aux1_accuracy: 0.2160 - aux2_accuracy: 0.1893 - val_loss: 10.7305 - val_final_loss: 3.6286 - val_aux1_loss: 3.4973 - val_aux2_loss: 3.6045 - val_final_accuracy: 0.1861 - val_aux1_accuracy: 0.2139 - val_aux2_accuracy: 0.1958
# Epoch 4/50
# 704/704 [==============================] - 187s 265ms/step - loss: 9.8732 - final_loss: 3.4074 - aux1_loss: 3.1611 - aux2_loss: 3.3047 - final_accuracy: 0.2241 - aux1_accuracy: 0.2671 - aux2_accuracy: 0.2418 - val_loss: 10.2159 - val_final_loss: 3.4501 - val_aux1_loss: 3.3335 - val_aux2_loss: 3.4324 - val_final_accuracy: 0.2166 - val_aux1_accuracy: 0.2480 - val_aux2_accuracy: 0.2238
# Epoch 5/50
# 704/704 [==============================] - 191s 271ms/step - loss: 9.1190 - final_loss: 3.1537 - aux1_loss: 2.9071 - aux2_loss: 3.0582 - final_accuracy: 0.2697 - aux1_accuracy: 0.3147 - aux2_accuracy: 0.2873 - val_loss: 9.6762 - val_final_loss: 3.2150 - val_aux1_loss: 3.2024 - val_aux2_loss: 3.2588 - val_final_accuracy: 0.2650 - val_aux1_accuracy: 0.2705 - val_aux2_accuracy: 0.2581
# Epoch 6/50
# 704/704 [==============================] - 192s 273ms/step - loss: 8.4311 - final_loss: 2.9304 - aux1_loss: 2.6654 - aux2_loss: 2.8352 - final_accuracy: 0.3082 - aux1_accuracy: 0.3574 - aux2_accuracy: 0.3246 - val_loss: 9.6574 - val_final_loss: 3.1873 - val_aux1_loss: 3.2254 - val_aux2_loss: 3.2447 - val_final_accuracy: 0.2751 - val_aux1_accuracy: 0.2755 - val_aux2_accuracy: 0.2667
# Epoch 7/50
# 704/704 [==============================] - 188s 267ms/step - loss: 7.7859 - final_loss: 2.7245 - aux1_loss: 2.4365 - aux2_loss: 2.6249 - final_accuracy: 0.3496 - aux1_accuracy: 0.4005 - aux2_accuracy: 0.3654 - val_loss: 9.6304 - val_final_loss: 3.1659 - val_aux1_loss: 3.2342 - val_aux2_loss: 3.2303 - val_final_accuracy: 0.2777 - val_aux1_accuracy: 0.2819 - val_aux2_accuracy: 0.2729
# Epoch 8/50
# 704/704 [==============================] - 187s 265ms/step - loss: 7.1870 - final_loss: 2.5372 - aux1_loss: 2.2131 - aux2_loss: 2.4368 - final_accuracy: 0.3833 - aux1_accuracy: 0.4431 - aux2_accuracy: 0.3991 - val_loss: 9.6350 - val_final_loss: 3.0797 - val_aux1_loss: 3.3006 - val_aux2_loss: 3.2547 - val_final_accuracy: 0.2982 - val_aux1_accuracy: 0.2852 - val_aux2_accuracy: 0.2789
# Epoch 9/50
# 704/704 [==============================] - 188s 267ms/step - loss: 6.5494 - final_loss: 2.3280 - aux1_loss: 1.9836 - aux2_loss: 2.2378 - final_accuracy: 0.4257 - aux1_accuracy: 0.4937 - aux2_accuracy: 0.4384 - val_loss: 9.5273 - val_final_loss: 2.9901 - val_aux1_loss: 3.3277 - val_aux2_loss: 3.2095 - val_final_accuracy: 0.3189 - val_aux1_accuracy: 0.2879 - val_aux2_accuracy: 0.2926
# Epoch 10/50
# 704/704 [==============================] - 187s 266ms/step - loss: 5.9328 - final_loss: 2.1249 - aux1_loss: 1.7558 - aux2_loss: 2.0520 - final_accuracy: 0.4658 - aux1_accuracy: 0.5407 - aux2_accuracy: 0.4764 - val_loss: 10.4073 - val_final_loss: 3.2834 - val_aux1_loss: 3.6266 - val_aux2_loss: 3.4973 - val_final_accuracy: 0.2928 - val_aux1_accuracy: 0.2776 - val_aux2_accuracy: 0.2753
# Epoch 11/50
# 704/704 [==============================] - 190s 270ms/step - loss: 5.2519 - final_loss: 1.8908 - aux1_loss: 1.5145 - aux2_loss: 1.8465 - final_accuracy: 0.5147 - aux1_accuracy: 0.5928 - aux2_accuracy: 0.5185 - val_loss: 10.4919 - val_final_loss: 3.2112 - val_aux1_loss: 3.7836 - val_aux2_loss: 3.4971 - val_final_accuracy: 0.3082 - val_aux1_accuracy: 0.2764 - val_aux2_accuracy: 0.2839
# Epoch 12/50
# 704/704 [==============================] - 193s 275ms/step - loss: 4.6043 - final_loss: 1.6496 - aux1_loss: 1.2993 - aux2_loss: 1.6554 - final_accuracy: 0.5651 - aux1_accuracy: 0.6418 - aux2_accuracy: 0.5597 - val_loss: 11.2169 - val_final_loss: 3.4254 - val_aux1_loss: 4.0509 - val_aux2_loss: 3.7406 - val_final_accuracy: 0.3122 - val_aux1_accuracy: 0.2695 - val_aux2_accuracy: 0.2793
# Epoch 13/50
# 704/704 [==============================] - 190s 271ms/step - loss: 3.9591 - final_loss: 1.4115 - aux1_loss: 1.0868 - aux2_loss: 1.4607 - final_accuracy: 0.6181 - aux1_accuracy: 0.6925 - aux2_accuracy: 0.6017 - val_loss: 11.9197 - val_final_loss: 3.5946 - val_aux1_loss: 4.4064 - val_aux2_loss: 3.9187 - val_final_accuracy: 0.2977 - val_aux1_accuracy: 0.2632 - val_aux2_accuracy: 0.2768
# Epoch 14/50
# 704/704 [==============================] - 193s 274ms/step - loss: 3.3747 - final_loss: 1.1841 - aux1_loss: 0.9025 - aux2_loss: 1.2881 - final_accuracy: 0.6703 - aux1_accuracy: 0.7374 - aux2_accuracy: 0.6412 - val_loss: 12.7538 - val_final_loss: 3.8684 - val_aux1_loss: 4.7397 - val_aux2_loss: 4.1457 - val_final_accuracy: 0.2993 - val_aux1_accuracy: 0.2625 - val_aux2_accuracy: 0.2716
# Epoch 15/50
# 704/704 [==============================] - 191s 271ms/step - loss: 2.8006 - final_loss: 0.9609 - aux1_loss: 0.7273 - aux2_loss: 1.1124 - final_accuracy: 0.7246 - aux1_accuracy: 0.7843 - aux2_accuracy: 0.6819 - val_loss: 14.1164 - val_final_loss: 4.2496 - val_aux1_loss: 5.3256 - val_aux2_loss: 4.5412 - val_final_accuracy: 0.2876 - val_aux1_accuracy: 0.2518 - val_aux2_accuracy: 0.2553
# Epoch 16/50
# 704/704 [==============================] - 187s 266ms/step - loss: 2.3706 - final_loss: 0.7997 - aux1_loss: 0.6078 - aux2_loss: 0.9631 - final_accuracy: 0.7632 - aux1_accuracy: 0.8142 - aux2_accuracy: 0.7183 - val_loss: 15.1394 - val_final_loss: 4.6011 - val_aux1_loss: 5.6468 - val_aux2_loss: 4.8915 - val_final_accuracy: 0.2853 - val_aux1_accuracy: 0.2512 - val_aux2_accuracy: 0.2628
# Epoch 17/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.9684 - final_loss: 0.6462 - aux1_loss: 0.4904 - aux2_loss: 0.8319 - final_accuracy: 0.8055 - aux1_accuracy: 0.8466 - aux2_accuracy: 0.7504 - val_loss: 16.7570 - val_final_loss: 5.1116 - val_aux1_loss: 6.3542 - val_aux2_loss: 5.2912 - val_final_accuracy: 0.2815 - val_aux1_accuracy: 0.2413 - val_aux2_accuracy: 0.2497
# Epoch 18/50
# 704/704 [==============================] - 187s 266ms/step - loss: 1.7058 - final_loss: 0.5504 - aux1_loss: 0.4245 - aux2_loss: 0.7309 - final_accuracy: 0.8313 - aux1_accuracy: 0.8651 - aux2_accuracy: 0.7764 - val_loss: 17.5668 - val_final_loss: 5.3087 - val_aux1_loss: 6.6925 - val_aux2_loss: 5.5656 - val_final_accuracy: 0.2769 - val_aux1_accuracy: 0.2522 - val_aux2_accuracy: 0.2538
# Epoch 19/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.4803 - final_loss: 0.4726 - aux1_loss: 0.3660 - aux2_loss: 0.6417 - final_accuracy: 0.8522 - aux1_accuracy: 0.8823 - aux2_accuracy: 0.8009 - val_loss: 18.7395 - val_final_loss: 5.6182 - val_aux1_loss: 7.0680 - val_aux2_loss: 6.0532 - val_final_accuracy: 0.2848 - val_aux1_accuracy: 0.2405 - val_aux2_accuracy: 0.2457
# Epoch 20/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.3435 - final_loss: 0.4393 - aux1_loss: 0.3262 - aux2_loss: 0.5780 - final_accuracy: 0.8619 - aux1_accuracy: 0.8940 - aux2_accuracy: 0.8181 - val_loss: 19.6525 - val_final_loss: 5.9494 - val_aux1_loss: 7.5241 - val_aux2_loss: 6.1789 - val_final_accuracy: 0.2774 - val_aux1_accuracy: 0.2413 - val_aux2_accuracy: 0.2483
# Epoch 21/50
# 704/704 [==============================] - 187s 266ms/step - loss: 1.2174 - final_loss: 0.3938 - aux1_loss: 0.3054 - aux2_loss: 0.5182 - final_accuracy: 0.8751 - aux1_accuracy: 0.9012 - aux2_accuracy: 0.8357 - val_loss: 20.5491 - val_final_loss: 6.2095 - val_aux1_loss: 7.7076 - val_aux2_loss: 6.6320 - val_final_accuracy: 0.2734 - val_aux1_accuracy: 0.2404 - val_aux2_accuracy: 0.2409
# Epoch 22/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.1569 - final_loss: 0.3784 - aux1_loss: 0.2911 - aux2_loss: 0.4873 - final_accuracy: 0.8798 - aux1_accuracy: 0.9046 - aux2_accuracy: 0.8446 - val_loss: 21.4164 - val_final_loss: 6.4535 - val_aux1_loss: 7.9431 - val_aux2_loss: 7.0198 - val_final_accuracy: 0.2738 - val_aux1_accuracy: 0.2488 - val_aux2_accuracy: 0.2472
# Epoch 23/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.0581 - final_loss: 0.3450 - aux1_loss: 0.2679 - aux2_loss: 0.4452 - final_accuracy: 0.8900 - aux1_accuracy: 0.9139 - aux2_accuracy: 0.8570 - val_loss: 21.2719 - val_final_loss: 6.2677 - val_aux1_loss: 8.0720 - val_aux2_loss: 6.9322 - val_final_accuracy: 0.2742 - val_aux1_accuracy: 0.2329 - val_aux2_accuracy: 0.2406
# Epoch 24/50
# 704/704 [==============================] - 187s 265ms/step - loss: 1.0091 - final_loss: 0.3373 - aux1_loss: 0.2442 - aux2_loss: 0.4276 - final_accuracy: 0.8929 - aux1_accuracy: 0.9197 - aux2_accuracy: 0.8618 - val_loss: 22.4865 - val_final_loss: 6.7577 - val_aux1_loss: 8.2965 - val_aux2_loss: 7.4323 - val_final_accuracy: 0.2821 - val_aux1_accuracy: 0.2483 - val_aux2_accuracy: 0.2490
# Epoch 25/50
# 704/704 [==============================] - 188s 266ms/step - loss: 0.9683 - final_loss: 0.3193 - aux1_loss: 0.2415 - aux2_loss: 0.4076 - final_accuracy: 0.8978 - aux1_accuracy: 0.9214 - aux2_accuracy: 0.8682 - val_loss: 22.6377 - val_final_loss: 6.7710 - val_aux1_loss: 8.5209 - val_aux2_loss: 7.3457 - val_final_accuracy: 0.2747 - val_aux1_accuracy: 0.2454 - val_aux2_accuracy: 0.2478
# Epoch 26/50
# 704/704 [==============================] - 190s 270ms/step - loss: 0.9378 - final_loss: 0.3143 - aux1_loss: 0.2384 - aux2_loss: 0.3851 - final_accuracy: 0.9016 - aux1_accuracy: 0.9224 - aux2_accuracy: 0.8751 - val_loss: 23.4350 - val_final_loss: 6.9737 - val_aux1_loss: 8.6614 - val_aux2_loss: 7.8000 - val_final_accuracy: 0.2692 - val_aux1_accuracy: 0.2413 - val_aux2_accuracy: 0.2395
# Epoch 27/50
# 704/704 [==============================] - 189s 269ms/step - loss: 0.8949 - final_loss: 0.3053 - aux1_loss: 0.2214 - aux2_loss: 0.3682 - final_accuracy: 0.9039 - aux1_accuracy: 0.9289 - aux2_accuracy: 0.8813 - val_loss: 23.1215 - val_final_loss: 6.8216 - val_aux1_loss: 8.6848 - val_aux2_loss: 7.6151 - val_final_accuracy: 0.2717 - val_aux1_accuracy: 0.2446 - val_aux2_accuracy: 0.2493
# Epoch 28/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.8632 - final_loss: 0.2874 - aux1_loss: 0.2188 - aux2_loss: 0.3570 - final_accuracy: 0.9088 - aux1_accuracy: 0.9289 - aux2_accuracy: 0.8854 - val_loss: 23.6481 - val_final_loss: 7.2423 - val_aux1_loss: 8.5279 - val_aux2_loss: 7.8779 - val_final_accuracy: 0.2615 - val_aux1_accuracy: 0.2436 - val_aux2_accuracy: 0.2351
# Epoch 29/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.8351 - final_loss: 0.2884 - aux1_loss: 0.2071 - aux2_loss: 0.3396 - final_accuracy: 0.9100 - aux1_accuracy: 0.9326 - aux2_accuracy: 0.8913 - val_loss: 23.0748 - val_final_loss: 6.8410 - val_aux1_loss: 8.6828 - val_aux2_loss: 7.5510 - val_final_accuracy: 0.2817 - val_aux1_accuracy: 0.2394 - val_aux2_accuracy: 0.2512
# Epoch 30/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.8123 - final_loss: 0.2868 - aux1_loss: 0.2002 - aux2_loss: 0.3253 - final_accuracy: 0.9106 - aux1_accuracy: 0.9346 - aux2_accuracy: 0.8946 - val_loss: 24.3197 - val_final_loss: 7.1893 - val_aux1_loss: 9.1551 - val_aux2_loss: 7.9753 - val_final_accuracy: 0.2713 - val_aux1_accuracy: 0.2332 - val_aux2_accuracy: 0.2363
# Epoch 31/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.7963 - final_loss: 0.2792 - aux1_loss: 0.1946 - aux2_loss: 0.3226 - final_accuracy: 0.9124 - aux1_accuracy: 0.9375 - aux2_accuracy: 0.8961 - val_loss: 24.1061 - val_final_loss: 6.8868 - val_aux1_loss: 9.1748 - val_aux2_loss: 8.0446 - val_final_accuracy: 0.2721 - val_aux1_accuracy: 0.2390 - val_aux2_accuracy: 0.2381
# Epoch 32/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.7807 - final_loss: 0.2671 - aux1_loss: 0.1962 - aux2_loss: 0.3173 - final_accuracy: 0.9156 - aux1_accuracy: 0.9375 - aux2_accuracy: 0.8981 - val_loss: 24.1470 - val_final_loss: 7.2483 - val_aux1_loss: 8.9150 - val_aux2_loss: 7.9837 - val_final_accuracy: 0.2752 - val_aux1_accuracy: 0.2413 - val_aux2_accuracy: 0.2451
# Epoch 33/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.7723 - final_loss: 0.2768 - aux1_loss: 0.1892 - aux2_loss: 0.3063 - final_accuracy: 0.9142 - aux1_accuracy: 0.9398 - aux2_accuracy: 0.9012 - val_loss: 24.5654 - val_final_loss: 7.4291 - val_aux1_loss: 8.9104 - val_aux2_loss: 8.2259 - val_final_accuracy: 0.2779 - val_aux1_accuracy: 0.2507 - val_aux2_accuracy: 0.2463
# Epoch 34/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.7335 - final_loss: 0.2587 - aux1_loss: 0.1809 - aux2_loss: 0.2939 - final_accuracy: 0.9190 - aux1_accuracy: 0.9417 - aux2_accuracy: 0.9058 - val_loss: 25.1740 - val_final_loss: 7.3565 - val_aux1_loss: 9.3397 - val_aux2_loss: 8.4778 - val_final_accuracy: 0.2736 - val_aux1_accuracy: 0.2406 - val_aux2_accuracy: 0.2467
# Epoch 35/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.7234 - final_loss: 0.2533 - aux1_loss: 0.1693 - aux2_loss: 0.3008 - final_accuracy: 0.9205 - aux1_accuracy: 0.9446 - aux2_accuracy: 0.9033 - val_loss: 25.2834 - val_final_loss: 7.3610 - val_aux1_loss: 9.5331 - val_aux2_loss: 8.3893 - val_final_accuracy: 0.2687 - val_aux1_accuracy: 0.2345 - val_aux2_accuracy: 0.2397
# Epoch 36/50
# 704/704 [==============================] - 189s 268ms/step - loss: 0.7035 - final_loss: 0.2521 - aux1_loss: 0.1663 - aux2_loss: 0.2851 - final_accuracy: 0.9204 - aux1_accuracy: 0.9466 - aux2_accuracy: 0.9085 - val_loss: 24.7163 - val_final_loss: 7.2526 - val_aux1_loss: 9.3385 - val_aux2_loss: 8.1252 - val_final_accuracy: 0.2780 - val_aux1_accuracy: 0.2381 - val_aux2_accuracy: 0.2508
# Epoch 37/50
# 704/704 [==============================] - 189s 268ms/step - loss: 0.7035 - final_loss: 0.2566 - aux1_loss: 0.1678 - aux2_loss: 0.2792 - final_accuracy: 0.9195 - aux1_accuracy: 0.9464 - aux2_accuracy: 0.9102 - val_loss: 26.3656 - val_final_loss: 7.8761 - val_aux1_loss: 9.6809 - val_aux2_loss: 8.8086 - val_final_accuracy: 0.2705 - val_aux1_accuracy: 0.2343 - val_aux2_accuracy: 0.2373
# Epoch 38/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.6972 - final_loss: 0.2462 - aux1_loss: 0.1737 - aux2_loss: 0.2773 - final_accuracy: 0.9229 - aux1_accuracy: 0.9437 - aux2_accuracy: 0.9100 - val_loss: 26.1989 - val_final_loss: 7.7611 - val_aux1_loss: 9.6376 - val_aux2_loss: 8.8002 - val_final_accuracy: 0.2683 - val_aux1_accuracy: 0.2409 - val_aux2_accuracy: 0.2458
# Epoch 39/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.6837 - final_loss: 0.2460 - aux1_loss: 0.1692 - aux2_loss: 0.2685 - final_accuracy: 0.9231 - aux1_accuracy: 0.9455 - aux2_accuracy: 0.9134 - val_loss: 25.5013 - val_final_loss: 7.5540 - val_aux1_loss: 9.4731 - val_aux2_loss: 8.4742 - val_final_accuracy: 0.2737 - val_aux1_accuracy: 0.2363 - val_aux2_accuracy: 0.2447
# Epoch 40/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.6641 - final_loss: 0.2403 - aux1_loss: 0.1584 - aux2_loss: 0.2654 - final_accuracy: 0.9252 - aux1_accuracy: 0.9490 - aux2_accuracy: 0.9156 - val_loss: 25.6284 - val_final_loss: 7.5023 - val_aux1_loss: 9.5548 - val_aux2_loss: 8.5713 - val_final_accuracy: 0.2797 - val_aux1_accuracy: 0.2422 - val_aux2_accuracy: 0.2459
# Epoch 41/50
# 704/704 [==============================] - 187s 266ms/step - loss: 0.6489 - final_loss: 0.2392 - aux1_loss: 0.1528 - aux2_loss: 0.2569 - final_accuracy: 0.9251 - aux1_accuracy: 0.9503 - aux2_accuracy: 0.9180 - val_loss: 27.0777 - val_final_loss: 7.9917 - val_aux1_loss: 10.0207 - val_aux2_loss: 9.0652 - val_final_accuracy: 0.2626 - val_aux1_accuracy: 0.2410 - val_aux2_accuracy: 0.2417
# Epoch 42/50
# 704/704 [==============================] - 188s 267ms/step - loss: 0.6538 - final_loss: 0.2286 - aux1_loss: 0.1585 - aux2_loss: 0.2667 - final_accuracy: 0.9290 - aux1_accuracy: 0.9489 - aux2_accuracy: 0.9141 - val_loss: 25.7146 - val_final_loss: 7.6038 - val_aux1_loss: 9.4281 - val_aux2_loss: 8.6827 - val_final_accuracy: 0.2718 - val_aux1_accuracy: 0.2425 - val_aux2_accuracy: 0.2474
# Epoch 43/50
# 704/704 [==============================] - 189s 268ms/step - loss: 0.6111 - final_loss: 0.2269 - aux1_loss: 0.1400 - aux2_loss: 0.2441 - final_accuracy: 0.9293 - aux1_accuracy: 0.9551 - aux2_accuracy: 0.9218 - val_loss: 26.4504 - val_final_loss: 7.6069 - val_aux1_loss: 10.0566 - val_aux2_loss: 8.7869 - val_final_accuracy: 0.2740 - val_aux1_accuracy: 0.2384 - val_aux2_accuracy: 0.2408
# Epoch 44/50
# 704/704 [==============================] - 188s 266ms/step - loss: 0.6440 - final_loss: 0.2394 - aux1_loss: 0.1496 - aux2_loss: 0.2549 - final_accuracy: 0.9251 - aux1_accuracy: 0.9523 - aux2_accuracy: 0.9180 - val_loss: 26.9409 - val_final_loss: 8.0343 - val_aux1_loss: 10.0430 - val_aux2_loss: 8.8636 - val_final_accuracy: 0.2732 - val_aux1_accuracy: 0.2430 - val_aux2_accuracy: 0.2514
# Epoch 45/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.6006 - final_loss: 0.2149 - aux1_loss: 0.1460 - aux2_loss: 0.2397 - final_accuracy: 0.9339 - aux1_accuracy: 0.9528 - aux2_accuracy: 0.9225 - val_loss: 26.9647 - val_final_loss: 7.8171 - val_aux1_loss: 10.2278 - val_aux2_loss: 8.9199 - val_final_accuracy: 0.2727 - val_aux1_accuracy: 0.2364 - val_aux2_accuracy: 0.2357
# Epoch 46/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.6113 - final_loss: 0.2274 - aux1_loss: 0.1510 - aux2_loss: 0.2329 - final_accuracy: 0.9300 - aux1_accuracy: 0.9518 - aux2_accuracy: 0.9254 - val_loss: 27.3011 - val_final_loss: 8.0565 - val_aux1_loss: 9.9808 - val_aux2_loss: 9.2637 - val_final_accuracy: 0.2675 - val_aux1_accuracy: 0.2393 - val_aux2_accuracy: 0.2433
# Epoch 47/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.5907 - final_loss: 0.2225 - aux1_loss: 0.1309 - aux2_loss: 0.2373 - final_accuracy: 0.9306 - aux1_accuracy: 0.9570 - aux2_accuracy: 0.9229 - val_loss: 26.9351 - val_final_loss: 7.8724 - val_aux1_loss: 10.1094 - val_aux2_loss: 8.9532 - val_final_accuracy: 0.2699 - val_aux1_accuracy: 0.2395 - val_aux2_accuracy: 0.2396
# Epoch 48/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.5981 - final_loss: 0.2286 - aux1_loss: 0.1358 - aux2_loss: 0.2337 - final_accuracy: 0.9293 - aux1_accuracy: 0.9561 - aux2_accuracy: 0.9246 - val_loss: 26.9302 - val_final_loss: 7.8122 - val_aux1_loss: 10.2298 - val_aux2_loss: 8.8881 - val_final_accuracy: 0.2615 - val_aux1_accuracy: 0.2425 - val_aux2_accuracy: 0.2409
# Epoch 49/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.5812 - final_loss: 0.2100 - aux1_loss: 0.1397 - aux2_loss: 0.2316 - final_accuracy: 0.9345 - aux1_accuracy: 0.9551 - aux2_accuracy: 0.9261 - val_loss: 26.7863 - val_final_loss: 7.8042 - val_aux1_loss: 9.9773 - val_aux2_loss: 9.0047 - val_final_accuracy: 0.2693 - val_aux1_accuracy: 0.2411 - val_aux2_accuracy: 0.2486
# Epoch 50/50
# 704/704 [==============================] - 187s 265ms/step - loss: 0.5882 - final_loss: 0.2127 - aux1_loss: 0.1365 - aux2_loss: 0.2390 - final_accuracy: 0.9342 - aux1_accuracy: 0.9564 - aux2_accuracy: 0.9236 - val_loss: 27.4269 - val_final_loss: 8.2502 - val_aux1_loss: 10.1467 - val_aux2_loss: 9.0300 - val_final_accuracy: 0.2690 - val_aux1_accuracy: 0.2373 - val_aux2_accuracy: 0.2437
# It took 9396.011547088623 seconds to complete the training

# %% [markdown]
# ## Bonus: Metrics of the model
#
# This is a multi output model. So it pays off to check what are the metrics that the model uses. You can get metric names by calling `model.metrics_names` as follows.

# %%
print(model.metrics_names)
# Out:
# ['loss', 'final_loss', 'aux1_loss', 'aux2_loss', 'final_accuracy', 'aux1_accuracy', 'aux2_accuracy']

# %% [markdown]
# ## Saving the trained model

# %%
# Save the model to models directory
if not os.path.exists('models'):
    os.mkdir("models")
model.save(os.path.join('models', 'inception_v1_base.h5'))

# %% [markdown]
# ## Get test accuracy of the trained model

# %%
# Section 6.4

# Load the model from disk
model = load_model(os.path.join('models','inception_v1_base.h5'))

# Evaluate the model
test_res = model.evaluate(test_gen_aux, steps=get_steps_per_epoch(500*50, batch_size))

# Print the results as a dictionary {<metric name>: <value>}
test_res_dict = dict(zip(model.metrics_names, test_res))
print(test_res_dict)
# Out:
# 196/196 [==============================] - 17s 85ms/step - loss: 27.5954 - final_loss: 8.3132 - aux1_loss: 10.1646 - aux2_loss: 9.1176 - final_accuracy: 0.2670 - aux1_accuracy: 0.2454 - aux2_accuracy: 0.2419
# {'loss': 27.595443725585938, 'final_loss': 8.31319522857666, 'aux1_loss': 10.164627075195312, 'aux2_loss': 9.11762809753418, 'final_accuracy': 0.2669723331928253, 'aux1_accuracy': 0.24537484347820282, 'aux2_accuracy': 0.2418757975101471}
